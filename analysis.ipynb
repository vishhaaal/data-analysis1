# %%
import os
for dirname, _, filenames in os.walk("C:\\Users\\Amisha\\Desktop\\data-analysis1\\csv-file"):
    for filename in filenames:
        print(os.path.join(dirname,filename))
# Out:
# C:\Users\Amisha\Desktop\data-analysis1\csv-file\salesdaily.csv
# C:\Users\Amisha\Desktop\data-analysis1\csv-file\saleshourly.csv
# C:\Users\Amisha\Desktop\data-analysis1\csv-file\salesmonthly.csv
# C:\Users\Amisha\Desktop\data-analysis1\csv-file\salesweekly.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\Amisha\\Desktop\\data-analysis1\\csv-file\\salesdaily.csv")

# %%
df.head()
# Out:
#       datum  M01AB  M01AE  N02BA  N02BE  N05B  N05C   R03  R06  Year  Month  \
# 0  1/2/2014    0.0   3.67    3.4  32.40   7.0   0.0   0.0  2.0  2014      1
# 1  1/3/2014    8.0   4.00    4.4  50.60  16.0   0.0  20.0  4.0  2014      1
# 2  1/4/2014    2.0   1.00    6.5  61.85  10.0   0.0   9.0  1.0  2014      1
# 3  1/5/2014    4.0   3.00    7.0  41.10   8.0   0.0   3.0  0.0  2014      1
# 4  1/6/2014    5.0   1.00    4.5  21.70  16.0   2.0   6.0  2.0  2014      1
#
#    Hour Weekday Name Time_stamp
# 0   248     Thursday 2014-01-02
# 1   276       Friday 2014-01-03
# 2   276     Saturday 2014-01-04
# 3   276       Sunday 2014-01-05
# 4   276       Monday 2014-01-06

# %%
df.describe()
# Out:
#              M01AB        M01AE        N02BA        N02BE         N05B  \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean      5.033683     3.895830     3.880441    29.917095     8.853627
# std       2.737579     2.133337     2.384010    15.590966     5.605605
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     2.340000     2.000000    19.000000     5.000000
# 50%       4.990000     3.670000     3.500000    26.900000     8.000000
# 75%       6.670000     5.138000     5.200000    38.300000    12.000000
# max      17.340000    14.463000    16.000000   161.000000    54.833333
#
#               N05C          R03          R06         Year        Month  \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean      0.593522     5.512262     2.900198  2016.401235     6.344255
# std       1.092988     6.428736     2.415816     1.665060     3.386954
# ...

# %%
df['Time_stamp'] = pd.to_datetime(df['datum'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2106 entries, 0 to 2105
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datum         2106 non-null   object
#  1   M01AB         2106 non-null   float64
#  2   M01AE         2106 non-null   float64
#  3   N02BA         2106 non-null   float64
#  4   N02BE         2106 non-null   float64
#  5   N05B          2106 non-null   float64
#  6   N05C          2106 non-null   float64
#  7   R03           2106 non-null   float64
#  8   R06           2106 non-null   float64
#  9   Year          2106 non-null   int64
#  10  Month         2106 non-null   int64
#  11  Hour          2106 non-null   int64
#  12  Weekday Name  2106 non-null   object
#  13  Time_stamp    2106 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(8), int64(3), object(2)
# memory usage: 230.5+ KB

# %%
null_count = df.isnull().sum()
print(null_count)
# Out:
# datum           0
# M01AB           0
# M01AE           0
# N02BA           0
# N02BE           0
# N05B            0
# N05C            0
# R03             0
# R06             0
# Year            0
# Month           0
# Hour            0
# Weekday Name    0
# Time_stamp      0
# dtype: int64

# %%
duplicate_files = df.duplicated().sum()
print(duplicate_files)
# Out:
# 0

# %%
df.corr()
# Out:
# C:\Users\Amisha\AppData\Local\Temp\ipykernel_12136\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           M01AB     M01AE     N02BA     N02BE      N05B      N05C       R03  \
# M01AB  1.000000  0.189982  0.147483  0.179634  0.030208  0.015622  0.082835
# M01AE  0.189982  1.000000  0.170372  0.291562  0.062396  0.026344  0.094250
# N02BA  0.147483  0.170372  1.000000  0.213752  0.175076  0.057120  0.037384
# N02BE  0.179634  0.291562  0.213752  1.000000  0.073080  0.002461  0.222892
# N05B   0.030208  0.062396  0.175076  0.073080  1.000000  0.246728  0.040026
# N05C   0.015622  0.026344  0.057120  0.002461  0.246728  1.000000  0.009548
# R03    0.082835  0.094250  0.037384  0.222892  0.040026  0.009548  1.000000
# ...

# %%
fig, ax = plt.subplots()
ax.grid([1,2,3,4,3,2])
ax.plot([1,2,3,4,3,2])
